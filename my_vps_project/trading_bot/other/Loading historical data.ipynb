# %%
from datetime import datetime
import stock_marker_binance
import time
import pandas as pd

# %%
def hours_to_milliseconds(hours):
    return hours * 60 * 60 * 1000

# %%
# Loading historical data from 1-Jan-2020 00:00:00 and saving it to csv file.
# convert string to datetime object

df_total = pd.DataFrame()
INTERVAL_START = datetime.strptime('2020-01-01 00:00:00.000', '%Y-%m-%d %H:%M:%S.%f')

INTERVAL_START = int ( time.mktime(INTERVAL_START.timetuple())*1000)

url = 'https://api3.binance.com/api/v3/time'

df_time_stop = pd.read_json(url, typ='series')
print('Server time: ', df_time_stop)
TIME_STOP = df_time_stop[0]
TIME_STOP = int ( time.mktime(TIME_STOP.timetuple())*1000)

# INTERVAL_START = int(INTERVAL_START.replace(tzinfo=timezone.utc).timestamp())
print("UNIX timestamp:", INTERVAL_START)
# Out:
# Server time:  serverTime   2024-02-05 06:42:39.107
# dtype: datetime64[ns]
# UNIX timestamp: 1577836800000
# C:\Users\user\AppData\Local\Temp\ipykernel_7208\2326828825.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   TIME_STOP = df_time_stop[0] + timedelta(hours=5)

# %%
SYMBOL = 'ETHUSDT'
INTERVAL = '1h'

# %%
while INTERVAL_START < TIME_STOP:
      df=stock_marker_binance.import_stock_data(SYMBOL, INTERVAL, startTime =INTERVAL_START, limit=984)
      df.rename(
          columns={0:'timestamp', 1:'open', 2:'high', 3:'low', 4:'close',5:'volume', 6:'close_time', 7:'quote_asset_volume',
                8:'num_trades', 9:'taker_buy_base_asset_volume',10:'taker_buy_quote_asset_volume', 11:'unused_field'},
         inplace=True)
      df.drop(columns=['taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'unused_field'], inplace=True)
      if len(df_total)>0:
            df_total = pd.concat([df_total, df], ignore_index=True)
      else:
            df_total = df.copy()
      INTERVAL_START = INTERVAL_START + hours_to_milliseconds(984)
      print(len(df_total))
# Out:
# 984
# 1968
# 2952
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 while INTERVAL_START < TIME_STOP:
# ----> 2       df=stock_marker_binance.import_stock_data(SYMBOL, INTERVAL, startTime =INTERVAL_START, limit=984)
#       3       df.rename(
#       4           columns={0:'timestamp', 1:'open', 2:'high', 3:'low', 4:'close',5:'volume', 6:'close_time', 7:'quote_asset_volume',
#       5                 8:'num_trades', 9:'taker_buy_base_asset_volume',10:'taker_buy_quote_asset_volume', 11:'unused_field'},
#       6          inplace=True)
#       7       df.drop(columns=['taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'unused_field'], inplace=True)
#
# File c:\Users\user\Documents\GitHub\BinanceTradingBot\stock_marker_binance.py:236, in import_stock_data(symbol, interval, startTime, endTime, limit)
#     233 url = url + '&limit=' + str(limit)
#     235 i = 5
# --> 236 df = pd.read_json(url)
#     237 while len(df)==0:
#     238     time.sleep(i)
#
# File c:\Users\user\miniconda3\Lib\site-packages\pandas\io\json\_json.py:780, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     777 if convert_axes is None and orient != "table":
#     778     convert_axes = True
# --> 780 json_reader = JsonReader(
#     781     path_or_buf,
#     782     orient=orient,
#     783     typ=typ,
#     784     dtype=dtype,
#     785     convert_axes=convert_axes,
#     786     convert_dates=convert_dates,
#     787     keep_default_dates=keep_default_dates,
#     788     precise_float=precise_float,
#     789     date_unit=date_unit,
#     790     encoding=encoding,
#     791     lines=lines,
#     792     chunksize=chunksize,
#     793     compression=compression,
#     794     nrows=nrows,
#     795     storage_options=storage_options,
#     796     encoding_errors=encoding_errors,
#     797     dtype_backend=dtype_backend,
#     798     engine=engine,
#     799 )
#     801 if chunksize:
#     802     return json_reader
#
# File c:\Users\user\miniconda3\Lib\site-packages\pandas\io\json\_json.py:893, in JsonReader.__init__(self, filepath_or_buffer, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, lines, chunksize, compression, nrows, storage_options, encoding_errors, dtype_backend, engine)
#     891     self.data = filepath_or_buffer
#     892 elif self.engine == "ujson":
# --> 893     data = self._get_data_from_filepath(filepath_or_buffer)
#     894     self.data = self._preprocess_data(data)
#
# File c:\Users\user\miniconda3\Lib\site-packages\pandas\io\json\_json.py:933, in JsonReader._get_data_from_filepath(self, filepath_or_buffer)
#     926 filepath_or_buffer = stringify_path(filepath_or_buffer)
#     927 if (
#     928     not isinstance(filepath_or_buffer, str)
#     929     or is_url(filepath_or_buffer)
#     930     or is_fsspec_url(filepath_or_buffer)
#     931     or file_exists(filepath_or_buffer)
#     932 ):
# --> 933     self.handles = get_handle(
#     934         filepath_or_buffer,
#     935         "r",
#     936         encoding=self.encoding,
#     937         compression=self.compression,
#     938         storage_options=self.storage_options,
#     939         errors=self.encoding_errors,
#     940     )
#     941     filepath_or_buffer = self.handles.handle
#     942 elif (
#     943     isinstance(filepath_or_buffer, str)
#     944     and filepath_or_buffer.lower().endswith(
#    (...)
#     947     and not file_exists(filepath_or_buffer)
#     948 ):
#
# File c:\Users\user\miniconda3\Lib\site-packages\pandas\io\common.py:718, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     715     codecs.lookup_error(errors)
#     717 # open URLs
# --> 718 ioargs = _get_filepath_or_buffer(
#     719     path_or_buf,
#     720     encoding=encoding,
#     721     compression=compression,
#     722     mode=mode,
#     723     storage_options=storage_options,
#     724 )
#     726 handle = ioargs.filepath_or_buffer
#     727 handles: list[BaseBuffer]
#
# File c:\Users\user\miniconda3\Lib\site-packages\pandas\io\common.py:377, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     374         if content_encoding == "gzip":
#     375             # Override compression based on Content-Encoding header
#     376             compression = {"method": "gzip"}
# --> 377         reader = BytesIO(req.read())
#     378     return IOArgs(
#     379         filepath_or_buffer=reader,
#     380         encoding=encoding,
#    (...)
#     383         mode=fsspec_mode,
#     384     )
#     386 if is_fsspec_url(filepath_or_buffer):
#
# File c:\Users\user\miniconda3\Lib\http\client.py:482, in HTTPResponse.read(self, amt)
#     480 else:
#     481     try:
# --> 482         s = self._safe_read(self.length)
#     483     except IncompleteRead:
#     484         self._close_conn()
#
# File c:\Users\user\miniconda3\Lib\http\client.py:631, in HTTPResponse._safe_read(self, amt)
#     624 def _safe_read(self, amt):
#     625     """Read the number of bytes requested.
#     626
#     627     This function should be used when <amt> bytes "should" be present for
#     628     reading. If the bytes are truly not available (due to EOF), then the
#     629     IncompleteRead exception can be used to detect the problem.
#     630     """
# --> 631     data = self.fp.read(amt)
#     632     if len(data) < amt:
#     633         raise IncompleteRead(data, amt-len(data))
#
# File c:\Users\user\miniconda3\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File c:\Users\user\miniconda3\Lib\ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\user\miniconda3\Lib\ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df_total.tail()
# Out:
#                 timestamp     open     high      low    close     volume  \
# 35259 2024-01-09 03:00:00  2312.09  2314.69  2307.02  2309.13  9382.4544
# 35260 2024-01-09 04:00:00  2309.12  2318.00  2300.40  2315.20  8726.1326
# 35261 2024-01-09 05:00:00  2315.20  2319.01  2301.40  2308.77  9108.7656
# 35262 2024-01-09 06:00:00  2308.77  2309.08  2297.26  2302.00  8630.9460
# 35263 2024-01-09 07:00:00  2302.00  2310.64  2298.58  2306.60  6331.7233
#
#           close_time  quote_asset_volume  num_trades
# 35259  1704772799999        2.168060e+07       20175
# 35260  1704776399999        2.015283e+07       21479
# 35261  1704779999999        2.103808e+07       20845
# 35262  1704783599999        1.988220e+07       21123
# 35263  1704787199999        1.459177e+07       13559

# %%
df_total.to_csv('ETH_1h_history as of 03-02-2024.csv')

# %%
df
# Out:
#               timestamp     open     high      low    close      volume  \
# 0   2023-12-06 00:00:00  2293.33  2312.23  2287.78  2310.11  27743.0211
# 1   2023-12-06 01:00:00  2310.10  2311.66  2285.37  2294.99  19507.7099
# 2   2023-12-06 02:00:00  2294.99  2298.32  2275.17  2292.00  17298.3737
# 3   2023-12-06 03:00:00  2292.00  2292.77  2273.94  2281.80  15095.9563
# 4   2023-12-06 04:00:00  2281.80  2284.75  2272.40  2278.85  11677.7878
# ..                  ...      ...      ...      ...      ...         ...
# 819 2024-01-09 03:00:00  2312.09  2314.69  2307.02  2309.13   9382.4544
# 820 2024-01-09 04:00:00  2309.12  2318.00  2300.40  2315.20   8726.1326
# 821 2024-01-09 05:00:00  2315.20  2319.01  2301.40  2308.77   9108.7656
# 822 2024-01-09 06:00:00  2308.77  2309.08  2297.26  2302.00   8630.9460
# 823 2024-01-09 07:00:00  2302.00  2310.64  2298.58  2306.60   6331.7233
#
#         close_time  quote_asset_volume  num_trades
# 0    1701824399999        6.376270e+07       52817
# 1    1701827999999        4.483248e+07       44423
# 2    1701831599999        3.955371e+07       36308
# 3    1701835199999        3.446575e+07       28392
# 4    1701838799999        2.661989e+07       22616
# ..             ...                 ...         ...
# 819  1704772799999        2.168060e+07       20175
# 820  1704776399999        2.015283e+07       21479
# 821  1704779999999        2.103808e+07       20845
# 822  1704783599999        1.988220e+07       21123
# 823  1704787199999        1.459177e+07       13559
#
# [824 rows x 9 columns]

# %%
df.dtypes
# Out:
# timestamp             datetime64[ns]
# open                         float64
# high                         float64
# low                          float64
# close                        float64
# volume                       float64
# close_time                     int64
# quote_asset_volume           float64
# num_trades                     int64
# dtype: object
